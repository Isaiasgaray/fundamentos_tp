# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pyarrow as pa
import pyarrow.parquet as pq

# %%
data = pd.read_csv('../datasets/provicias_datos_2022.csv',
                   delimiter=';',
                   header=3)

# %%
data.head()
# Out:
#                          PROVINCIa  población (miles)  hogares (miles)  \
# 0  Ciudad Autónoma de Buenos Aires              3.004            1.263
# 1                     Buenos Aires             17.292            5.738
# 2                        Catamarca            336.000          102.000
# 3                            Chaco              3.477            1.251
# 4                           Chubut            967.000          287.000
#
#   ingresos laborales (miles pesos) tasa de empleo (%) superficie (km2)  \
# 0                      211.877.384                4,7            205,9
# 1                      623.250.917                8,7       305.907,40
# 2                        8.460.986                7,3       101.486,10
# 3                      122.790.341                6,5        99.763,30
# 4                       24.733.558                5,3       224.302,30
#
#   exportaciones (mill usd)
# 0                  311,163
# 1                33024,657
# 2                   201,03
# 3                  516,336
# 4                 2575,372

# %%
data.tail()
# Out:
#               PROVINCIa  población (miles)  hogares (miles)  \
# 19           Santa Cruz            379.000          133.000
# 20             Santa Fe              3.311            1.215
# 21  Santiago del Estero            730.000          213.000
# 22              Tucumán              1.403          403.000
# 23     Tierra del Fuego            172.000           60.000
#
#    ingresos laborales (miles pesos) tasa de empleo (%) superficie (km2)  \
# 19                       19.517.125                5,1       244.457,50
# 20                      135.661.847                5,4       133.249,10
# 21                       16.504.869               3.0        136.934,30
# 22                       34.757.143                6,3       910.324,40
# 23                       12.059.449                110        22.592,10
#
#    exportaciones (mill usd)
# 19                 2242,114
# 20                 19162,52
# 21                 1545,387
# 22                  953,715
# 23                  382,966
